# %% [markdown]
# # Run FinData benchmark over Postgresql
#
# ### Create database

# %%
# %pip install sqlalchemy
# %pip install psycopg
# %pip install ipython-sql
# Out:
# Requirement already satisfied: psycopg in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (3.1.4)
# Requirement already satisfied: typing-extensions>=4.1 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from psycopg) (4.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipython-sql in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (0.4.1)
# Requirement already satisfied: prettytable<1 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: six in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython-sql) (1.4.44)
# Requirement already satisfied: sqlparse in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython-sql) (8.4.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (65.5.0)
# Requirement already satisfied: pickleshare in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: stack-data in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: backcall in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (2.11.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.1.6)
# Requirement already satisfied: decorator in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: appnope in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: traitlets>=5 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from sqlalchemy>=0.6.7->ipython-sql) (2.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: asttokens in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.5)
# Requirement already satisfied: executing in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: pure-eval in /usr/local/Caskroom/miniconda/base/envs/kdb/lib/python3.9/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
import psycopg
try:
    conn= psycopg.connect("dbname=postgres user=postgres", autocommit=True)
    with conn.cursor() as cur:
        cur.execute("DROP DATABASE IF EXISTS findata")
        cur.execute("CREATE DATABASE findata")
finally:
    if conn:
        conn.close()

# %%
# postgresql://username:password@hostname/dbname
connection_string = "postgresql://postgres@localhost/findata"
# %sql $connection_string

# %%
# %%sql
# DROP TABLE IF EXISTS ticks;
# DROP TABLE IF EXISTS base;
# CREATE TABLE IF NOT EXISTS base(
#   Id    varchar(40) PRIMARY KEY NOT NULL,
#   Ex    varchar(5),
#   Descr varchar(260),
#   SIC   varchar(30),
#   Cu    varchar(30)
# );
# CREATE TABLE IF NOT EXISTS ticks(
#   TickID      serial PRIMARY KEY,
#   Id          varchar(40) NOT NULL ,
#   SeqNo       bigint,
#   TradeDate   date,
#   Ts          time,
#   TradePrice  float,
#   TradeSize   float,
#   AskPrice    float,
#   AskSize     float,
#   BidPrice    float,
#   BidSize     float,
#   Type_       char(3),
#   CONSTRAINT fk_security_id
#     FOREIGN KEY(Id) REFERENCES base(Id)
# );
# Out:
#    postgresql://alfredo.leon@localhost/findata
#  * postgresql://postgres@localhost/findata
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ### Load Data

# %%
base_path='/Users/alfredo.leon/Desktop/findata/data/scale_1000/tick_base_file_no_spaces.csv'
ticks_path='/Users/alfredo.leon/Desktop/findata/data/scale_1000/tick_price_file_no_spaces.csv'

# %%
# %%sql
# COPY base(Id, Ex, Descr, SIC, Cu)
# FROM '{base_path}' DELIMITER '|' CSV HEADER;
#
# COPY ticks(Id, SeqNo, TradeDate, Ts, TradePrice, TradeSize, AskPrice, AskSize, BidPrice, BidSize, Type_)
# FROM '{ticks_path}'
# DELIMITER '|' CSV HEADER;
# Out:
#    postgresql://alfredo.leon@localhost/findata
#  * postgresql://postgres@localhost/findata
# 1000 rows affected.
# 531498 rows affected.
# []

# %% [markdown]
# ### Metrics

# %% [markdown]
# ### Queries

# %%
# %%time
# %%sql
-- 1.
SELECT *
FROM ticks
WHERE Id IN (SELECT Id From base LIMIT 100)
  AND TradeDate = '2022.11.21'
  AND ts >= '9:00:00.00'
  AND ts < '12:00:00.00';
# Out:
#    postgresql://alfredo.leon@localhost/findata
#  * postgresql://postgres@localhost/findata
# 4223 rows affected.
# CPU times: user 19.4 ms, sys: 38.8 ms, total: 58.1 ms
# Wall time: 623 ms
# [(10, 'Security_27', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 2), 31.0, 5600.0, None, None, None, None, 'CT '),
#  (19, 'Security_95', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 4), None, None, 1.0, 8100.0, None, None, 'Q  '),
#  (30, 'Security_79', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 7), 39.0, 5900.0, None, None, None, None, 'T  '),
#  (50, 'Security_60', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 12), 72.0, 400.0, None, None, None, None, 'T  '),
#  (63, 'Security_22', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 16), None, None, 18.0625, 8700.0, None, None, 'Q  '),
#  (77, 'Security_86', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 19), None, None, None, None, 29.0312, 5300.0, 'Q  '),
#  (81, 'Security_4', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 20), 62.0, 3200.0, None, None, None, None, 'T  '),
#  (94, 'Security_20', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 24), None, None, 55.0938, 9400.0, None, None, 'Q  '),
#  (109, 'Security_38', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 27), None, None, 29.0, 100.0, None, None, 'Q  '),
#  (121, 'Security_29', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 30), None, None, None, None, 11.0625, 7800.0, 'Q  '),
#  (132, 'Security_92', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 33), None, None, 2.0625, 4400.0, None, None, 'Q  '),
#  (148, 'Security_80', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 37), None, None, 80.0312, 4300.0, None, None, 'Q  '),
#  (158, 'Security_71', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 40), None, None, None, None, 92.0, 2700.0, 'Q  '),
#  (162, 'Security_96', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 41), 0.0, 5400.0, None, None, None, None, 'T  '),
#  (170, 'Security_15', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 43), 31.0, 8500.0, None, None, None, None, 'CT '),
#  (184, 'Security_22', 2, datetime.date(2022, 11, 21), datetime.time(9, 0, 46), 18.0, 8800.0, None, None, None, None, 'T  '),
#  (198, 'Security_95', 2, datetime.date(2022, 11, 21), datetime.time(9, 0, 50), None, None, None, None, 1.0, 6000.0, 'Q  '),
#  (203, 'Security_73', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 51), None, None, 66.0938, 1100.0, None, None, 'Q  '),
#  (208, 'Security_2', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 52), None, None, None, None, 90.0312, 7300.0, 'Q  '),
#  (209, 'Security_51', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 52), None, None, 32.0938, 3900.0, None, None, 'Q  '),
#  (214, 'Security_69', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 54), 77.0, 2000.0, None, None, None, None, 'T  '),
#  (234, 'Security_46', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 59), None, None, 47.0938, 5300.0, None, None, 'Q  '),
#  (237, 'Security_18', 1, datetime.date(2022, 11, 21), datetime.time(9, 0, 59), 45.0, 3800.0, None, None, None, None, 'CT '),
#  (244, 'Security_75', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 1), None, None, None, None, 35.0625, 9300.0, 'Q  '),
#  (245, 'Security_64', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 1), 56.0, 4700.0, None, None, None, None, 'CT '),
#  (248, 'Security_15', 2, datetime.date(2022, 11, 21), datetime.time(9, 1, 2), None, None, 31.0312, 8100.0, None, None, 'Q  '),
#  (272, 'Security_84', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 8), 46.0, 7600.0, None, None, None, None, 'T  '),
#  (279, 'Security_52', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 10), 20.0, 7900.0, None, None, None, None, 'CT '),
#  (291, 'Security_54', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 13), None, None, None, None, 26.9688, 4900.0, 'Q  '),
#  (297, 'Security_5', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 15), None, None, 43.0312, 7500.0, None, None, 'Q  '),
#  (299, 'Security_46', 2, datetime.date(2022, 11, 21), datetime.time(9, 1, 15), 47.0, 2400.0, None, None, None, None, 'T  '),
#  (312, 'Security_82', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 19), 31.0, 600.0, None, None, None, None, 'T  '),
#  (325, 'Security_20', 2, datetime.date(2022, 11, 21), datetime.time(9, 1, 22), None, None, None, None, 55.0312, 8500.0, 'Q  '),
#  (327, 'Security_16', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 22), 97.0, 8900.0, None, None, None, None, 'T  '),
#  (357, 'Security_92', 2, datetime.date(2022, 11, 21), datetime.time(9, 1, 30), 2.0, 9500.0, None, None, None, None, 'CT '),
#  (359, 'Security_69', 2, datetime.date(2022, 11, 21), datetime.time(9, 1, 31), 77.0, 3600.0, None, None, None, None, 'CT '),
#  (363, 'Security_81', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 32), 95.0, 7100.0, None, None, None, None, 'CT '),
#  (364, 'Security_65', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 32), 54.0, 3500.0, None, None, None, None, 'T  '),
#  (388, 'Security_25', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 38), 75.0, 2500.0, None, None, None, None, 'CT '),
#  (398, 'Security_22', 3, datetime.date(2022, 11, 21), datetime.time(9, 1, 40), None, None, None, None, 18.0312, 3500.0, 'Q  '),
#  (408, 'Security_58', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 43), 49.0, 5800.0, None, None, None, None, 'T  '),
#  (422, 'Security_71', 2, datetime.date(2022, 11, 21), datetime.time(9, 1, 46), 92.0, 500.0, None, None, None, None, 'CT '),
#  (427, 'Security_49', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 48), None, None, None, None, 61.9375, 3600.0, 'Q  '),
#  (441, 'Security_17', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 51), None, None, 76.0625, 7700.0, None, None, 'Q  '),
#  (447, 'Security_48', 1, datetime.date(2022, 11, 21), datetime.time(9, 1, 53), None, None, None, None, 63.0625, 300.0, 'Q  '),
#  (452, 'Security_16', 2, datetime.date(2022, 11, 21), datetime.time(9, 1, 54), 97.0, 6500.0, None, None, None, None, 'T  '),
#  (461, 'Security_60', 2, datetime.date(2022, 11, 21), datetime.time(9, 1, 56), None, None, 72.0, 6500.0, None, None, 'Q  '),
#  (479, 'Security_36', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 1), None, None, None, None, 51.0, 9700.0, 'Q  '),
#  (487, 'Security_80', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 3), 80.0, 6500.0, None, None, None, None, 'T  '),
#  (489, 'Security_88', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 3), None, None, 32.0938, 4300.0, None, None, 'Q  '),
#  (492, 'Security_93', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 4), None, None, 73.0625, 400.0, None, None, 'Q  '),
#  (502, 'Security_63', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 7), 15.0, 3700.0, None, None, None, None, 'T  '),
#  (512, 'Security_93', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 9), None, None, 73.0625, 7600.0, None, None, 'Q  '),
#  (523, 'Security_93', 3, datetime.date(2022, 11, 21), datetime.time(9, 2, 12), 73.0, 6600.0, None, None, None, None, 'CT '),
#  (528, 'Security_60', 3, datetime.date(2022, 11, 21), datetime.time(9, 2, 13), None, None, 72.0, 1100.0, None, None, 'Q  '),
#  (534, 'Security_27', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 15), None, None, None, None, 31.0312, 3700.0, 'Q  '),
#  (538, 'Security_5', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 16), 43.0, 300.0, None, None, None, None, 'CT '),
#  (547, 'Security_54', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 18), 26.9688, 3400.0, None, None, None, None, 'CT '),
#  (560, 'Security_17', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 21), None, None, None, None, 75.9688, 3400.0, 'Q  '),
#  (568, 'Security_68', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 23), 33.0, 600.0, None, None, None, None, 'T  '),
#  (592, 'Security_18', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 29), None, None, 45.0938, 7000.0, None, None, 'Q  '),
#  (600, 'Security_23', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 31), None, None, None, None, 52.9375, 5000.0, 'Q  '),
#  (612, 'Security_87', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 34), 98.0, 2200.0, None, None, None, None, 'T  '),
#  (619, 'Security_33', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 36), None, None, 69.0, 8800.0, None, None, 'Q  '),
#  (621, 'Security_52', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 36), 20.0, 1800.0, None, None, None, None, 'CT '),
#  (622, 'Security_9', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 37), None, None, 61.0, 800.0, None, None, 'Q  '),
#  (625, 'Security_37', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 37), None, None, 97.0, 2400.0, None, None, 'Q  '),
#  (627, 'Security_72', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 38), 81.0, 9800.0, None, None, None, None, 'CT '),
#  (635, 'Security_44', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 40), 15.0, 6600.0, None, None, None, None, 'T  '),
#  (650, 'Security_72', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 44), None, None, None, None, 81.0312, 8700.0, 'Q  '),
#  (653, 'Security_49', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 44), None, None, None, None, 61.9375, 6300.0, 'Q  '),
#  (691, 'Security_48', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 54), 63.0625, 6200.0, None, None, None, None, 'CT '),
#  (695, 'Security_4', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 55), None, None, None, None, 62.0625, 4900.0, 'Q  '),
#  (698, 'Security_63', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 56), None, None, 15.0, 5900.0, None, None, 'Q  '),
#  (701, 'Security_92', 3, datetime.date(2022, 11, 21), datetime.time(9, 2, 56), None, None, 2.09375, 7900.0, None, None, 'Q  '),
#  (702, 'Security_26', 1, datetime.date(2022, 11, 21), datetime.time(9, 2, 57), 5.0, 4200.0, None, None, None, None, 'T  '),
#  (707, 'Security_27', 3, datetime.date(2022, 11, 21), datetime.time(9, 2, 58), 31.0312, 3900.0, None, None, None, None, 'T  '),
#  (709, 'Security_75', 2, datetime.date(2022, 11, 21), datetime.time(9, 2, 58), None, None, None, None, 35.0625, 1600.0, 'Q  '),
#  (721, 'Security_11', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 1), None, None, 73.0938, 1300.0, None, None, 'Q  '),
#  (749, 'Security_63', 3, datetime.date(2022, 11, 21), datetime.time(9, 3, 9), 15.0, 100.0, None, None, None, None, 'T  '),
#  (756, 'Security_73', 2, datetime.date(2022, 11, 21), datetime.time(9, 3, 10), 66.0, 5600.0, None, None, None, None, 'CT '),
#  (759, 'Security_45', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 11), None, None, 87.0, 9100.0, None, None, 'Q  '),
#  (760, 'Security_16', 3, datetime.date(2022, 11, 21), datetime.time(9, 3, 11), 97.0, 700.0, None, None, None, None, 'CT '),
#  (779, 'Security_22', 4, datetime.date(2022, 11, 21), datetime.time(9, 3, 16), 18.0312, 8000.0, None, None, None, None, 'T  '),
#  (790, 'Security_60', 4, datetime.date(2022, 11, 21), datetime.time(9, 3, 19), 72.0, 3900.0, None, None, None, None, 'CT '),
#  (793, 'Security_28', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 20), None, None, 94.0312, 7000.0, None, None, 'Q  '),
#  (802, 'Security_5', 3, datetime.date(2022, 11, 21), datetime.time(9, 3, 22), None, None, 43.0625, 5800.0, None, None, 'Q  '),
#  (805, 'Security_1', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 23), None, None, 4.0, 7500.0, None, None, 'Q  '),
#  (810, 'Security_5', 4, datetime.date(2022, 11, 21), datetime.time(9, 3, 24), 43.0, 2600.0, None, None, None, None, 'T  '),
#  (812, 'Security_90', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 25), 50.0, 5800.0, None, None, None, None, 'CT '),
#  (815, 'Security_71', 3, datetime.date(2022, 11, 21), datetime.time(9, 3, 25), 92.0, 7500.0, None, None, None, None, 'T  '),
#  (818, 'Security_83', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 26), None, None, 82.0938, 1400.0, None, None, 'Q  '),
#  (827, 'Security_93', 4, datetime.date(2022, 11, 21), datetime.time(9, 3, 29), None, None, None, None, 73.0, 5000.0, 'Q  '),
#  (847, 'Security_33', 2, datetime.date(2022, 11, 21), datetime.time(9, 3, 34), 69.0, 2100.0, None, None, None, None, 'T  '),
#  (848, 'Security_39', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 34), None, None, None, None, 76.0625, 9000.0, 'Q  '),
#  (850, 'Security_20', 3, datetime.date(2022, 11, 21), datetime.time(9, 3, 34), None, None, None, None, 55.0312, 6700.0, 'Q  '),
#  (852, 'Security_23', 2, datetime.date(2022, 11, 21), datetime.time(9, 3, 35), None, None, 53.0312, 2800.0, None, None, 'Q  '),
#  (863, 'Security_84', 2, datetime.date(2022, 11, 21), datetime.time(9, 3, 38), None, None, None, None, 46.0, 2400.0, 'Q  '),
#  (875, 'Security_52', 3, datetime.date(2022, 11, 21), datetime.time(9, 3, 41), 20.0, 4800.0, None, None, None, None, 'T  '),
#  (879, 'Security_66', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 42), None, None, None, None, 3.0, 1200.0, 'Q  '),
#  (887, 'Security_1', 2, datetime.date(2022, 11, 21), datetime.time(9, 3, 44), 4.0, 5800.0, None, None, None, None, 'CT '),
#  (896, 'Security_90', 2, datetime.date(2022, 11, 21), datetime.time(9, 3, 46), 50.0, 6200.0, None, None, None, None, 'T  '),
#  (897, 'Security_81', 2, datetime.date(2022, 11, 21), datetime.time(9, 3, 46), 95.0, 6000.0, None, None, None, None, 'T  '),
#  (924, 'Security_7', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 53), None, None, 47.0, 5300.0, None, None, 'Q  '),
#  (925, 'Security_91', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 53), None, None, 42.0, 5000.0, None, None, 'Q  '),
#  (937, 'Security_70', 1, datetime.date(2022, 11, 21), datetime.time(9, 3, 56), None, None, None, None, 60.9375, 7500.0, 'Q  '),
#  (943, 'Security_68', 2, datetime.date(2022, 11, 21), datetime.time(9, 3, 58), 33.0, 700.0, None, None, None, None, 'T  '),
#  (954, 'Security_7', 2, datetime.date(2022, 11, 21), datetime.time(9, 4, 1), 47.0, 2100.0, None, None, None, None, 'T  '),
#  (959, 'Security_54', 3, datetime.date(2022, 11, 21), datetime.time(9, 4, 2), None, None, 26.9688, 6400.0, None, None, 'Q  '),
#  (961, 'Security_63', 4, datetime.date(2022, 11, 21), datetime.time(9, 4, 2), 15.0, 7100.0, None, None, None, None, 'CT '),
#  (987, 'Security_77', 1, datetime.date(2022, 11, 21), datetime.time(9, 4, 9), 49.0, 1900.0, None, None, None, None, 'CT '),
#  (990, 'Security_86', 2, datetime.date(2022, 11, 21), datetime.time(9, 4, 10), 29.0312, 5800.0, None, None, None, None, 'T  '),
#  (1013, 'Security_2', 2, datetime.date(2022, 11, 21), datetime.time(9, 4, 15), None, None, 90.0625, 4800.0, None, None, 'Q  '),
#  (1016, 'Security_56', 1, datetime.date(2022, 11, 21), datetime.time(9, 4, 16), None, None, 25.0312, 7100.0, None, None, 'Q  '),
#  (1020, 'Security_31', 1, datetime.date(2022, 11, 21), datetime.time(9, 4, 17), None, None, 68.0938, 9200.0, None, None, 'Q  '),
#  (1059, 'Security_77', 2, datetime.date(2022, 11, 21), datetime.time(9, 4, 27), None, None, None, None, 48.9375, 1600.0, 'Q  '),
#  (1076, 'Security_20', 4, datetime.date(2022, 11, 21), datetime.time(9, 4, 31), 55.0312, 3800.0, None, None, None, None, 'CT '),
#  (1091, 'Security_62', 1, datetime.date(2022, 11, 21), datetime.time(9, 4, 35), 53.0, 2100.0, None, None, None, None, 'CT '),
#  (1101, 'Security_32', 1, datetime.date(2022, 11, 21), datetime.time(9, 4, 38), 82.0, 3800.0, None, None, None, None, 'T  '),
#  (1118, 'Security_95', 3, datetime.date(2022, 11, 21), datetime.time(9, 4, 42), None, None, None, None, 1.0, 3300.0, 'Q  '),
#  (1119, 'Security_30', 1, datetime.date(2022, 11, 21), datetime.time(9, 4, 42), None, None, None, None, 22.0, 9700.0, 'Q  '),
#  (1140, 'Security_50', 1, datetime.date(2022, 11, 21), datetime.time(9, 4, 47), None, None, 43.0312, 2700.0, None, None, 'Q  '),
#  (1178, 'Security_6', 1, datetime.date(2022, 11, 21), datetime.time(9, 4, 57), 58.0, 7500.0, None, None, None, None, 'T  '),
#  (1180, 'Security_39', 2, datetime.date(2022, 11, 21), datetime.time(9, 4, 58), 76.0625, 700.0, None, None, None, None, 'T  '),
#  (1182, 'Security_18', 3, datetime.date(2022, 11, 21), datetime.time(9, 4, 58), 45.0, 8400.0, None, None, None, None, 'T  '),
#  (1194, 'Security_79', 2, datetime.date(2022, 11, 21), datetime.time(9, 5, 1), 39.0, 2500.0, None, None, None, None, 'CT '),
#  (1206, 'Security_59', 1, datetime.date(2022, 11, 21), datetime.time(9, 5, 4), None, None, None, None, 90.0625, 4700.0, 'Q  '),
#  (1210, 'Security_0', 1, datetime.date(2022, 11, 21), datetime.time(9, 5, 5), 95.0, 5500.0, None, None, None, None, 'T  '),
#  (1237, 'Security_28', 2, datetime.date(2022, 11, 21), datetime.time(9, 5, 12), None, None, None, None, 94.0312, 9100.0, 'Q  '),
#  (1241, 'Security_52', 4, datetime.date(2022, 11, 21), datetime.time(9, 5, 13), None, None, 20.0938, 2100.0, None, None, 'Q  '),
#  (1277, 'Security_5', 5, datetime.date(2022, 11, 21), datetime.time(9, 5, 22), None, None, 43.0625, 1800.0, None, None, 'Q  '),
#  (1297, 'Security_11', 2, datetime.date(2022, 11, 21), datetime.time(9, 5, 27), None, None, 73.0, 8300.0, None, None, 'Q  '),
#  (1310, 'Security_95', 4, datetime.date(2022, 11, 21), datetime.time(9, 5, 30), 1.0, 6700.0, None, None, None, None, 'T  '),
#  (1311, 'Security_51', 2, datetime.date(2022, 11, 21), datetime.time(9, 5, 30), None, None, 32.0938, 2300.0, None, None, 'Q  '),
#  (1353, 'Security_78', 1, datetime.date(2022, 11, 21), datetime.time(9, 5, 41), None, None, 68.0938, 6000.0, None, None, 'Q  '),
#  (1357, 'Security_29', 2, datetime.date(2022, 11, 21), datetime.time(9, 5, 42), 11.0625, 2500.0, None, None, None, None, 'CT '),
#  (1358, 'Security_13', 1, datetime.date(2022, 11, 21), datetime.time(9, 5, 43), None, None, None, None, 27.0312, 200.0, 'Q  '),
#  (1370, 'Security_85', 1, datetime.date(2022, 11, 21), datetime.time(9, 5, 46), 27.0, 900.0, None, None, None, None, 'T  '),
#  (1374, 'Security_18', 4, datetime.date(2022, 11, 21), datetime.time(9, 5, 47), 45.0, 6000.0, None, None, None, None, 'T  '),
#  (1378, 'Security_55', 1, datetime.date(2022, 11, 21), datetime.time(9, 5, 48), None, None, 27.0, 1200.0, None, None, 'Q  '),
#  (1405, 'Security_76', 1, datetime.date(2022, 11, 21), datetime.time(9, 5, 55), None, None, 83.0625, 6700.0, None, None, 'Q  '),
#  (1408, 'Security_89', 1, datetime.date(2022, 11, 21), datetime.time(9, 5, 56), None, None, None, None, 85.0625, 3000.0, 'Q  '),
#  (1413, 'Security_16', 4, datetime.date(2022, 11, 21), datetime.time(9, 5, 57), 97.0, 700.0, None, None, None, None, 'T  '),
#  (1415, 'Security_83', 2, datetime.date(2022, 11, 21), datetime.time(9, 5, 58), 82.0, 6400.0, None, None, None, None, 'CT '),
#  (1428, 'Security_77', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 1), None, None, 49.0, 6600.0, None, None, 'Q  '),
#  (1438, 'Security_13', 2, datetime.date(2022, 11, 21), datetime.time(9, 6, 3), None, None, None, None, 26.9688, 3500.0, 'Q  '),
#  (1473, 'Security_44', 2, datetime.date(2022, 11, 21), datetime.time(9, 6, 12), 15.0, 6300.0, None, None, None, None, 'T  '),
#  (1474, 'Security_90', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 12), None, None, None, None, 50.0, 9000.0, 'Q  '),
#  (1479, 'Security_84', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 14), None, None, 46.0, 7100.0, None, None, 'Q  '),
#  (1495, 'Security_85', 2, datetime.date(2022, 11, 21), datetime.time(9, 6, 18), 27.0, 3200.0, None, None, None, None, 'CT '),
#  (1496, 'Security_86', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 18), 29.0312, 9200.0, None, None, None, None, 'T  '),
#  (1521, 'Security_94', 1, datetime.date(2022, 11, 21), datetime.time(9, 6, 24), None, None, None, None, 66.9688, 8800.0, 'Q  '),
#  (1526, 'Security_36', 2, datetime.date(2022, 11, 21), datetime.time(9, 6, 26), 51.0, 4700.0, None, None, None, None, 'T  '),
#  (1538, 'Security_21', 1, datetime.date(2022, 11, 21), datetime.time(9, 6, 29), None, None, 12.0312, 5200.0, None, None, 'Q  '),
#  (1543, 'Security_81', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 30), None, None, None, None, 95.0, 5300.0, 'Q  '),
#  (1562, 'Security_24', 1, datetime.date(2022, 11, 21), datetime.time(9, 6, 35), 46.0, 8300.0, None, None, None, None, 'CT '),
#  (1582, 'Security_86', 4, datetime.date(2022, 11, 21), datetime.time(9, 6, 40), 29.0312, 3600.0, None, None, None, None, 'T  '),
#  (1598, 'Security_38', 2, datetime.date(2022, 11, 21), datetime.time(9, 6, 44), 29.0, 5300.0, None, None, None, None, 'CT '),
#  (1602, 'Security_88', 2, datetime.date(2022, 11, 21), datetime.time(9, 6, 45), None, None, 32.0938, 4700.0, None, None, 'Q  '),
#  (1603, 'Security_61', 1, datetime.date(2022, 11, 21), datetime.time(9, 6, 45), None, None, 53.0, 2900.0, None, None, 'Q  '),
#  (1605, 'Security_85', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 46), None, None, None, None, 26.9688, 3100.0, 'Q  '),
#  (1607, 'Security_46', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 46), 47.0, 4700.0, None, None, None, None, 'T  '),
#  (1611, 'Security_88', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 47), 32.0, 9400.0, None, None, None, None, 'CT '),
#  (1637, 'Security_51', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 54), None, None, 32.0, 8600.0, None, None, 'Q  '),
#  (1644, 'Security_16', 5, datetime.date(2022, 11, 21), datetime.time(9, 6, 56), 97.0, 4800.0, None, None, None, None, 'CT '),
#  (1645, 'Security_35', 1, datetime.date(2022, 11, 21), datetime.time(9, 6, 56), 58.0, 8900.0, None, None, None, None, 'CT '),
#  (1651, 'Security_29', 3, datetime.date(2022, 11, 21), datetime.time(9, 6, 57), 11.0625, 2700.0, None, None, None, None, 'T  '),
#  (1659, 'Security_94', 2, datetime.date(2022, 11, 21), datetime.time(9, 6, 59), None, None, None, None, 66.9375, 9400.0, 'Q  '),
#  (1662, 'Security_8', 1, datetime.date(2022, 11, 21), datetime.time(9, 7), None, None, 81.0312, 8100.0, None, None, 'Q  '),
#  (1663, 'Security_63', 5, datetime.date(2022, 11, 21), datetime.time(9, 7), 15.0, 400.0, None, None, None, None, 'CT '),
#  (1692, 'Security_50', 2, datetime.date(2022, 11, 21), datetime.time(9, 7, 8), None, None, 43.0, 6100.0, None, None, 'Q  '),
#  (1695, 'Security_65', 2, datetime.date(2022, 11, 21), datetime.time(9, 7, 8), 54.0, 600.0, None, None, None, None, 'CT '),
#  (1708, 'Security_34', 1, datetime.date(2022, 11, 21), datetime.time(9, 7, 12), None, None, 52.0312, 3400.0, None, None, 'Q  '),
#  (1731, 'Security_13', 3, datetime.date(2022, 11, 21), datetime.time(9, 7, 18), None, None, 26.9688, 1100.0, None, None, 'Q  '),
#  (1735, 'Security_46', 4, datetime.date(2022, 11, 21), datetime.time(9, 7, 19), 47.0, 2700.0, None, None, None, None, 'T  '),
#  (1759, 'Security_16', 6, datetime.date(2022, 11, 21), datetime.time(9, 7, 25), 97.0, 1000.0, None, None, None, None, 'CT '),
#  (1768, 'Security_91', 2, datetime.date(2022, 11, 21), datetime.time(9, 7, 27), 42.0, 7300.0, None, None, None, None, 'CT '),
#  (1778, 'Security_13', 4, datetime.date(2022, 11, 21), datetime.time(9, 7, 29), None, None, None, None, 26.9375, 7700.0, 'Q  '),
#  (1788, 'Security_28', 3, datetime.date(2022, 11, 21), datetime.time(9, 7, 32), None, None, 94.125, 6200.0, None, None, 'Q  '),
#  (1800, 'Security_32', 2, datetime.date(2022, 11, 21), datetime.time(9, 7, 35), None, None, 82.0312, 3700.0, None, None, 'Q  '),
#  (1813, 'Security_71', 4, datetime.date(2022, 11, 21), datetime.time(9, 7, 38), None, None, None, None, 92.0625, 5500.0, 'Q  '),
#  (1828, 'Security_68', 3, datetime.date(2022, 11, 21), datetime.time(9, 7, 42), None, None, 33.0, 1400.0, None, None, 'Q  '),
#  (1867, 'Security_47', 1, datetime.date(2022, 11, 21), datetime.time(9, 7, 52), None, None, 63.0, 9200.0, None, None, 'Q  '),
#  (1871, 'Security_85', 4, datetime.date(2022, 11, 21), datetime.time(9, 7, 53), None, None, None, None, 27.0312, 5900.0, 'Q  '),
#  (1902, 'Security_64', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 1), 56.0, 6800.0, None, None, None, None, 'T  '),
#  (1905, 'Security_97', 1, datetime.date(2022, 11, 21), datetime.time(9, 8, 1), 84.0, 2000.0, None, None, None, None, 'T  '),
#  (1914, 'Security_1', 3, datetime.date(2022, 11, 21), datetime.time(9, 8, 4), 4.0, 3500.0, None, None, None, None, 'T  '),
#  (1917, 'Security_39', 3, datetime.date(2022, 11, 21), datetime.time(9, 8, 4), None, None, 76.1562, 200.0, None, None, 'Q  '),
#  (1918, 'Security_8', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 5), None, None, None, None, 81.0625, 7100.0, 'Q  '),
#  (1921, 'Security_59', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 5), 90.0625, 8600.0, None, None, None, None, 'CT '),
#  (1935, 'Security_37', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 9), 97.0, 5300.0, None, None, None, None, 'T  '),
#  (1941, 'Security_87', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 10), None, None, None, None, 98.0, 4900.0, 'Q  '),
#  (1946, 'Security_77', 4, datetime.date(2022, 11, 21), datetime.time(9, 8, 12), None, None, None, None, 49.0, 2600.0, 'Q  '),
#  (1947, 'Security_30', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 12), 22.0, 3000.0, None, None, None, None, 'T  '),
#  (1961, 'Security_99', 1, datetime.date(2022, 11, 21), datetime.time(9, 8, 15), 87.0, 6400.0, None, None, None, None, 'T  '),
#  (1976, 'Security_47', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 19), None, None, None, None, 63.0312, 6600.0, 'Q  '),
#  (2015, 'Security_12', 1, datetime.date(2022, 11, 21), datetime.time(9, 8, 29), 20.0, 2400.0, None, None, None, None, 'T  '),
#  (2022, 'Security_17', 3, datetime.date(2022, 11, 21), datetime.time(9, 8, 31), 75.9688, 3200.0, None, None, None, None, 'CT '),
#  (2032, 'Security_40', 1, datetime.date(2022, 11, 21), datetime.time(9, 8, 34), 10.0, 5400.0, None, None, None, None, 'T  '),
#  (2033, 'Security_6', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 34), 58.0, 1900.0, None, None, None, None, 'CT '),
#  (2043, 'Security_56', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 36), 25.0, 8200.0, None, None, None, None, 'CT '),
#  (2114, 'Security_25', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 54), None, None, 75.0625, 2600.0, None, None, 'Q  '),
#  (2121, 'Security_2', 3, datetime.date(2022, 11, 21), datetime.time(9, 8, 56), None, None, None, None, 90.0938, 700.0, 'Q  '),
#  (2128, 'Security_70', 2, datetime.date(2022, 11, 21), datetime.time(9, 8, 58), None, None, None, None, 60.9062, 7200.0, 'Q  '),
#  (2144, 'Security_71', 5, datetime.date(2022, 11, 21), datetime.time(9, 9, 2), 92.0625, 9200.0, None, None, None, None, 'CT '),
#  (2146, 'Security_24', 2, datetime.date(2022, 11, 21), datetime.time(9, 9, 2), None, None, None, None, 46.0, 8100.0, 'Q  '),
#  (2147, 'Security_58', 2, datetime.date(2022, 11, 21), datetime.time(9, 9, 3), 49.0, 7100.0, None, None, None, None, 'CT '),
#  (2154, 'Security_47', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 4), None, None, 63.125, 3300.0, None, None, 'Q  '),
#  (2158, 'Security_28', 4, datetime.date(2022, 11, 21), datetime.time(9, 9, 5), 94.0312, 9500.0, None, None, None, None, 'CT '),
#  (2160, 'Security_11', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 6), 73.0, 4600.0, None, None, None, None, 'T  '),
#  (2167, 'Security_91', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 8), 42.0, 4400.0, None, None, None, None, 'T  '),
#  (2187, 'Security_58', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 13), None, None, None, None, 49.0, 300.0, 'Q  '),
#  (2193, 'Security_40', 2, datetime.date(2022, 11, 21), datetime.time(9, 9, 14), 10.0, 9100.0, None, None, None, None, 'T  '),
#  (2215, 'Security_46', 5, datetime.date(2022, 11, 21), datetime.time(9, 9, 20), 47.0, 2700.0, None, None, None, None, 'CT '),
#  (2225, 'Security_59', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 22), None, None, None, None, 90.0312, 1500.0, 'Q  '),
#  (2238, 'Security_66', 2, datetime.date(2022, 11, 21), datetime.time(9, 9, 25), None, None, None, None, 2.9375, 7300.0, 'Q  '),
#  (2250, 'Security_46', 6, datetime.date(2022, 11, 21), datetime.time(9, 9, 28), None, None, None, None, 47.0, 2400.0, 'Q  '),
#  (2251, 'Security_38', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 29), 29.0, 1000.0, None, None, None, None, 'CT '),
#  (2259, 'Security_48', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 31), None, None, 63.125, 7500.0, None, None, 'Q  '),
#  (2266, 'Security_89', 2, datetime.date(2022, 11, 21), datetime.time(9, 9, 32), 85.0625, 4200.0, None, None, None, None, 'T  '),
#  (2270, 'Security_75', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 33), 35.0625, 2000.0, None, None, None, None, 'CT '),
#  (2272, 'Security_9', 2, datetime.date(2022, 11, 21), datetime.time(9, 9, 34), 61.0, 1800.0, None, None, None, None, 'T  '),
#  (2283, 'Security_12', 2, datetime.date(2022, 11, 21), datetime.time(9, 9, 37), 20.0, 6100.0, None, None, None, None, 'CT '),
#  (2284, 'Security_4', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 37), 62.0625, 8300.0, None, None, None, None, 'T  '),
#  (2292, 'Security_44', 3, datetime.date(2022, 11, 21), datetime.time(9, 9, 39), None, None, None, None, 15.0625, 9600.0, 'Q  '),
#  (2294, 'Security_54', 4, datetime.date(2022, 11, 21), datetime.time(9, 9, 39), 26.9688, 5800.0, None, None, None, None, 'CT '),
#  (2297, 'Security_38', 4, datetime.date(2022, 11, 21), datetime.time(9, 9, 40), 29.0, 7600.0, None, None, None, None, 'CT '),
#  (2302, 'Security_85', 5, datetime.date(2022, 11, 21), datetime.time(9, 9, 41), 27.0312, 5000.0, None, None, None, None, 'T  '),
#  (2339, 'Security_52', 5, datetime.date(2022, 11, 21), datetime.time(9, 9, 51), 20.0, 600.0, None, None, None, None, 'T  '),
#  (2377, 'Security_36', 3, datetime.date(2022, 11, 21), datetime.time(9, 10), None, None, None, None, 50.9688, 1500.0, 'Q  '),
#  (2382, 'Security_37', 3, datetime.date(2022, 11, 21), datetime.time(9, 10, 1), None, None, 97.0938, 7800.0, None, None, 'Q  '),
#  (2390, 'Security_16', 7, datetime.date(2022, 11, 21), datetime.time(9, 10, 3), None, None, 97.0625, 8300.0, None, None, 'Q  '),
#  (2420, 'Security_47', 4, datetime.date(2022, 11, 21), datetime.time(9, 10, 11), 63.0312, 1900.0, None, None, None, None, 'T  '),
#  (3189, 'Security_49', 3, datetime.date(2022, 11, 21), datetime.time(9, 13, 26), None, None, None, None, 62.0, 4000.0, 'Q  '),
#  (2454, 'Security_31', 2, datetime.date(2022, 11, 21), datetime.time(9, 10, 20), 68.0, 3000.0, None, None, None, None, 'CT '),
#  (2458, 'Security_91', 4, datetime.date(2022, 11, 21), datetime.time(9, 10, 21), None, None, 42.0938, 5800.0, None, None, 'Q  '),
#  (2463, 'Security_28', 5, datetime.date(2022, 11, 21), datetime.time(9, 10, 22), 94.0312, 1300.0, None, None, None, None, 'T  '),
#  (2465, 'Security_5', 6, datetime.date(2022, 11, 21), datetime.time(9, 10, 22), None, None, None, None, 43.0, 1600.0, 'Q  '),
#  (2471, 'Security_89', 3, datetime.date(2022, 11, 21), datetime.time(9, 10, 24), None, None, None, None, 85.0312, 400.0, 'Q  '),
#  (2473, 'Security_11', 4, datetime.date(2022, 11, 21), datetime.time(9, 10, 24), None, None, 73.0625, 3500.0, None, None, 'Q  '),
#  (2499, 'Security_6', 3, datetime.date(2022, 11, 21), datetime.time(9, 10, 31), 58.0, 3400.0, None, None, None, None, 'CT '),
#  (2527, 'Security_69', 3, datetime.date(2022, 11, 21), datetime.time(9, 10, 38), 77.0, 6400.0, None, None, None, None, 'T  '),
#  (2535, 'Security_11', 5, datetime.date(2022, 11, 21), datetime.time(9, 10, 40), None, None, None, None, 72.9688, 6100.0, 'Q  '),
#  (2545, 'Security_27', 4, datetime.date(2022, 11, 21), datetime.time(9, 10, 42), None, None, 31.125, 5100.0, None, None, 'Q  '),
#  (2552, 'Security_93', 5, datetime.date(2022, 11, 21), datetime.time(9, 10, 44), None, None, None, None, 73.0312, 4500.0, 'Q  '),
#  (2557, 'Security_21', 2, datetime.date(2022, 11, 21), datetime.time(9, 10, 45), None, None, None, None, 12.0312, 5500.0, 'Q  '),
#  (2563, 'Security_46', 7, datetime.date(2022, 11, 21), datetime.time(9, 10, 47), 47.0, 7100.0, None, None, None, None, 'CT '),
#  (2587, 'Security_82', 2, datetime.date(2022, 11, 21), datetime.time(9, 10, 53), 31.0, 2000.0, None, None, None, None, 'CT '),
#  (2601, 'Security_60', 5, datetime.date(2022, 11, 21), datetime.time(9, 10, 57), 72.0, 400.0, None, None, None, None, 'CT '),
#  (2614, 'Security_76', 2, datetime.date(2022, 11, 21), datetime.time(9, 11), None, None, 83.0625, 5400.0, None, None, 'Q  '),
#  (2615, 'Security_4', 4, datetime.date(2022, 11, 21), datetime.time(9, 11), None, None, None, None, 62.0625, 200.0, 'Q  '),
#  (2619, 'Security_41', 1, datetime.date(2022, 11, 21), datetime.time(9, 11, 1), None, None, 16.0, 4500.0, None, None, 'Q  '),
#  (2624, 'Security_46', 8, datetime.date(2022, 11, 21), datetime.time(9, 11, 2), 47.0, 4600.0, None, None, None, None, 'CT '),
#  (2734, 'Security_53', 2, datetime.date(2022, 11, 21), datetime.time(9, 11, 30), None, None, None, None, 20.9688, 1400.0, 'Q  '),
#  (2742, 'Security_46', 9, datetime.date(2022, 11, 21), datetime.time(9, 11, 32), 47.0, 7600.0, None, None, None, None, 'CT '),
#  (2779, 'Security_3', 1, datetime.date(2022, 11, 21), datetime.time(9, 11, 42), None, None, None, None, 45.9375, 5200.0, 'Q  '),
#  (2783, 'Security_18', 5, datetime.date(2022, 11, 21), datetime.time(9, 11, 43), None, None, None, None, 44.9688, 9000.0, 'Q  '),
#  (2789, 'Security_32', 4, datetime.date(2022, 11, 21), datetime.time(9, 11, 44), 82.0, 2900.0, None, None, None, None, 'CT '),
#  (2794, 'Security_9', 3, datetime.date(2022, 11, 21), datetime.time(9, 11, 46), 61.0, 7600.0, None, None, None, None, 'T  '),
#  (2801, 'Security_36', 4, datetime.date(2022, 11, 21), datetime.time(9, 11, 47), None, None, 51.0, 100.0, None, None, 'Q  '),
#  (2832, 'Security_89', 4, datetime.date(2022, 11, 21), datetime.time(9, 11, 55), None, None, 85.0938, 5400.0, None, None, 'Q  '),
#  (2836, 'Security_93', 6, datetime.date(2022, 11, 21), datetime.time(9, 11, 56), 73.0312, 7400.0, None, None, None, None, 'CT '),
#  (2843, 'Security_53', 3, datetime.date(2022, 11, 21), datetime.time(9, 11, 58), 20.9688, 8900.0, None, None, None, None, 'CT '),
#  (2860, 'Security_64', 3, datetime.date(2022, 11, 21), datetime.time(9, 12, 2), 56.0, 8800.0, None, None, None, None, 'CT '),
#  (2873, 'Security_38', 5, datetime.date(2022, 11, 21), datetime.time(9, 12, 6), None, None, None, None, 29.0, 5300.0, 'Q  '),
#  (2895, 'Security_32', 5, datetime.date(2022, 11, 21), datetime.time(9, 12, 11), 82.0, 1000.0, None, None, None, None, 'CT '),
#  (2900, 'Security_91', 5, datetime.date(2022, 11, 21), datetime.time(9, 12, 13), None, None, None, None, 42.0, 3500.0, 'Q  '),
#  (2914, 'Security_89', 5, datetime.date(2022, 11, 21), datetime.time(9, 12, 16), 85.0312, 7200.0, None, None, None, None, 'CT '),
#  (2929, 'Security_59', 5, datetime.date(2022, 11, 21), datetime.time(9, 12, 20), 90.0312, 4200.0, None, None, None, None, 'T  '),
#  (2931, 'Security_47', 5, datetime.date(2022, 11, 21), datetime.time(9, 12, 20), 63.0312, 4900.0, None, None, None, None, 'T  '),
#  (2959, 'Security_15', 3, datetime.date(2022, 11, 21), datetime.time(9, 12, 28), None, None, None, None, 30.9375, 4000.0, 'Q  '),
#  (2963, 'Security_35', 2, datetime.date(2022, 11, 21), datetime.time(9, 12, 29), 58.0, 100.0, None, None, None, None, 'CT '),
#  (2969, 'Security_59', 6, datetime.date(2022, 11, 21), datetime.time(9, 12, 30), None, None, 90.0312, 5300.0, None, None, 'Q  '),
#  (2970, 'Security_8', 3, datetime.date(2022, 11, 21), datetime.time(9, 12, 30), 81.0625, 2500.0, None, None, None, None, 'CT '),
#  (2973, 'Security_38', 6, datetime.date(2022, 11, 21), datetime.time(9, 12, 31), 29.0, 200.0, None, None, None, None, 'T  '),
#  (2983, 'Security_1', 4, datetime.date(2022, 11, 21), datetime.time(9, 12, 34), 4.0, 9100.0, None, None, None, None, 'T  '),
#  (2994, 'Security_38', 7, datetime.date(2022, 11, 21), datetime.time(9, 12, 36), 29.0, 3300.0, None, None, None, None, 'CT '),
#  (2999, 'Security_34', 2, datetime.date(2022, 11, 21), datetime.time(9, 12, 38), None, None, None, None, 51.9688, 7600.0, 'Q  '),
#  (3000, 'Security_28', 6, datetime.date(2022, 11, 21), datetime.time(9, 12, 38), None, None, None, None, 94.0312, 1200.0, 'Q  '),
#  (3006, 'Security_89', 6, datetime.date(2022, 11, 21), datetime.time(9, 12, 39), None, None, None, None, 85.0312, 4100.0, 'Q  '),
#  (3008, 'Security_44', 4, datetime.date(2022, 11, 21), datetime.time(9, 12, 40), None, None, None, None, 15.0625, 5100.0, 'Q  '),
#  (3010, 'Security_30', 3, datetime.date(2022, 11, 21), datetime.time(9, 12, 40), 22.0, 3600.0, None, None, None, None, 'CT '),
#  (3646, 'Security_91', 7, datetime.date(2022, 11, 21), datetime.time(9, 15, 22), None, None, 42.0938, 2000.0, None, None, 'Q  '),
#  (3654, 'Security_10', 3, datetime.date(2022, 11, 21), datetime.time(9, 15, 24), None, None, None, None, 70.125, 1700.0, 'Q  '),
#  (3660, 'Security_84', 5, datetime.date(2022, 11, 21), datetime.time(9, 15, 26), None, None, None, None, 45.9375, 1700.0, 'Q  '),
#  (3669, 'Security_41', 2, datetime.date(2022, 11, 21), datetime.time(9, 15, 28), None, None, None, None, 16.0625, 8500.0, 'Q  '),
#  (3674, 'Security_46', 11, datetime.date(2022, 11, 21), datetime.time(9, 15, 30), None, None, 47.0938, 700.0, None, None, 'Q  '),
#  (3678, 'Security_82', 4, datetime.date(2022, 11, 21), datetime.time(9, 15, 31), None, None, 31.0938, 8600.0, None, None, 'Q  '),
#  (3690, 'Security_60', 7, datetime.date(2022, 11, 21), datetime.time(9, 15, 34), None, None, 72.0312, 7000.0, None, None, 'Q  '),
#  (3702, 'Security_96', 3, datetime.date(2022, 11, 21), datetime.time(9, 15, 37), 0.0, 5200.0, None, None, None, None, 'CT '),
#  (3703, 'Security_81', 4, datetime.date(2022, 11, 21), datetime.time(9, 15, 37), 95.0, 6800.0, None, None, None, None, 'CT '),
#  (3716, 'Security_41', 3, datetime.date(2022, 11, 21), datetime.time(9, 15, 40), 16.0625, 4400.0, None, None, None, None, 'T  '),
#  (3717, 'Security_6', 4, datetime.date(2022, 11, 21), datetime.time(9, 15, 40), 58.0, 5300.0, None, None, None, None, 'CT '),
#  (3722, 'Security_21', 5, datetime.date(2022, 11, 21), datetime.time(9, 15, 42), None, None, 12.0938, 5700.0, None, None, 'Q  '),
#  (3726, 'Security_20', 5, datetime.date(2022, 11, 21), datetime.time(9, 15, 43), 55.0312, 7200.0, None, None, None, None, 'T  '),
#  (3738, 'Security_70', 4, datetime.date(2022, 11, 21), datetime.time(9, 15, 46), None, None, None, None, 61.0312, 5000.0, 'Q  '),
#  (3743, 'Security_67', 1, datetime.date(2022, 11, 21), datetime.time(9, 15, 47), 63.0, 5900.0, None, None, None, None, 'CT '),
#  (3770, 'Security_66', 4, datetime.date(2022, 11, 21), datetime.time(9, 15, 54), None, None, None, None, 3.0, 6200.0, 'Q  '),
#  (3771, 'Security_8', 4, datetime.date(2022, 11, 21), datetime.time(9, 15, 54), 81.0625, 3800.0, None, None, None, None, 'T  '),
#  (3800, 'Security_10', 4, datetime.date(2022, 11, 21), datetime.time(9, 16, 2), 70.125, 9700.0, None, None, None, None, 'T  '),
#  (3807, 'Security_96', 4, datetime.date(2022, 11, 21), datetime.time(9, 16, 3), 0.0, 7100.0, None, None, None, None, 'T  '),
#  (3812, 'Security_22', 6, datetime.date(2022, 11, 21), datetime.time(9, 16, 5), None, None, 18.0625, 8500.0, None, None, 'Q  '),
#  (3818, 'Security_28', 8, datetime.date(2022, 11, 21), datetime.time(9, 16, 6), None, None, None, None, 93.9688, 9600.0, 'Q  '),
#  (3827, 'Security_46', 12, datetime.date(2022, 11, 21), datetime.time(9, 16, 8), None, None, None, None, 47.0625, 5600.0, 'Q  '),
#  (3832, 'Security_87', 4, datetime.date(2022, 11, 21), datetime.time(9, 16, 10), None, None, None, None, 98.0, 9800.0, 'Q  '),
#  (3833, 'Security_1', 6, datetime.date(2022, 11, 21), datetime.time(9, 16, 10), None, None, None, None, 4.0625, 900.0, 'Q  '),
#  (3837, 'Security_49', 5, datetime.date(2022, 11, 21), datetime.time(9, 16, 11), None, None, None, None, 62.0312, 7100.0, 'Q  '),
#  (3838, 'Security_56', 3, datetime.date(2022, 11, 21), datetime.time(9, 16, 11), None, None, 25.0625, 8500.0, None, None, 'Q  '),
#  (3844, 'Security_39', 5, datetime.date(2022, 11, 21), datetime.time(9, 16, 13), 76.0625, 1800.0, None, None, None, None, 'T  '),
#  (3850, 'Security_38', 8, datetime.date(2022, 11, 21), datetime.time(9, 16, 14), None, None, 29.0938, 1900.0, None, None, 'Q  '),
#  (3851, 'Security_2', 5, datetime.date(2022, 11, 21), datetime.time(9, 16, 15), None, None, 90.0938, 4300.0, None, None, 'Q  '),
#  (3861, 'Security_35', 4, datetime.date(2022, 11, 21), datetime.time(9, 16, 17), None, None, 58.0, 6800.0, None, None, 'Q  '),
#  (3874, 'Security_33', 6, datetime.date(2022, 11, 21), datetime.time(9, 16, 20), None, None, None, None, 69.0312, 2000.0, 'Q  '),
#  (3877, 'Security_70', 5, datetime.date(2022, 11, 21), datetime.time(9, 16, 21), None, None, 61.0625, 5600.0, None, None, 'Q  '),
#  (3894, 'Security_27', 6, datetime.date(2022, 11, 21), datetime.time(9, 16, 25), None, None, None, None, 31.0625, 1900.0, 'Q  '),
#  (3917, 'Security_69', 4, datetime.date(2022, 11, 21), datetime.time(9, 16, 31), 77.0, 4500.0, None, None, None, None, 'CT '),
#  (3924, 'Security_81', 5, datetime.date(2022, 11, 21), datetime.time(9, 16, 33), None, None, 95.0, 3500.0, None, None, 'Q  '),
#  (3939, 'Security_71', 7, datetime.date(2022, 11, 21), datetime.time(9, 16, 37), None, None, None, None, 92.125, 5800.0, 'Q  '),
#  (3942, 'Security_73', 5, datetime.date(2022, 11, 21), datetime.time(9, 16, 37), None, None, 66.0312, 6300.0, None, None, 'Q  '),
#  (3943, 'Security_11', 6, datetime.date(2022, 11, 21), datetime.time(9, 16, 38), 72.9688, 4300.0, None, None, None, None, 'T  '),
#  (3944, 'Security_53', 4, datetime.date(2022, 11, 21), datetime.time(9, 16, 38), 20.9688, 4600.0, None, None, None, None, 'T  '),
#  (4269, 'Security_83', 6, datetime.date(2022, 11, 21), datetime.time(9, 18, 1), None, None, None, None, 82.125, 500.0, 'Q  '),
#  (4273, 'Security_36', 8, datetime.date(2022, 11, 21), datetime.time(9, 18, 2), None, None, 51.0312, 3200.0, None, None, 'Q  '),
#  (4275, 'Security_32', 6, datetime.date(2022, 11, 21), datetime.time(9, 18, 2), 82.0, 2800.0, None, None, None, None, 'T  '),
#  (4279, 'Security_40', 3, datetime.date(2022, 11, 21), datetime.time(9, 18, 3), 10.0, 8100.0, None, None, None, None, 'T  '),
#  (4291, 'Security_64', 6, datetime.date(2022, 11, 21), datetime.time(9, 18, 6), None, None, None, None, 56.0625, 7400.0, 'Q  '),
#  (4293, 'Security_66', 5, datetime.date(2022, 11, 21), datetime.time(9, 18, 7), 3.0, 4000.0, None, None, None, None, 'T  '),
#  (4307, 'Security_51', 4, datetime.date(2022, 11, 21), datetime.time(9, 18, 10), None, None, None, None, 31.9688, 300.0, 'Q  '),
#  (4326, 'Security_33', 7, datetime.date(2022, 11, 21), datetime.time(9, 18, 15), 69.0312, 9400.0, None, None, None, None, 'CT '),
#  (4337, 'Security_79', 5, datetime.date(2022, 11, 21), datetime.time(9, 18, 18), 39.0, 8900.0, None, None, None, None, 'T  '),
#  (4349, 'Security_37', 5, datetime.date(2022, 11, 21), datetime.time(9, 18, 21), 97.0, 7900.0, None, None, None, None, 'T  '),
#  (4352, 'Security_88', 5, datetime.date(2022, 11, 21), datetime.time(9, 18, 22), 32.0, 1400.0, None, None, None, None, 'CT '),
#  (4369, 'Security_29', 6, datetime.date(2022, 11, 21), datetime.time(9, 18, 26), None, None, None, None, 11.125, 1100.0, 'Q  '),
#  (4384, 'Security_31', 4, datetime.date(2022, 11, 21), datetime.time(9, 18, 30), 68.0, 2100.0, None, None, None, None, 'T  '),
#  (4393, 'Security_24', 5, datetime.date(2022, 11, 21), datetime.time(9, 18, 32), None, None, 46.0, 9800.0, None, None, 'Q  '),
#  (4398, 'Security_19', 3, datetime.date(2022, 11, 21), datetime.time(9, 18, 33), None, None, None, None, 1.0, 7800.0, 'Q  '),
#  (4455, 'Security_79', 6, datetime.date(2022, 11, 21), datetime.time(9, 18, 48), None, None, 39.0625, 8000.0, None, None, 'Q  '),
#  (4461, 'Security_54', 7, datetime.date(2022, 11, 21), datetime.time(9, 18, 49), 26.9688, 9200.0, None, None, None, None, 'T  '),
#  (4473, 'Security_2', 7, datetime.date(2022, 11, 21), datetime.time(9, 18, 52), 90.0312, 8000.0, None, None, None, None, 'T  '),
#  (4500, 'Security_89', 7, datetime.date(2022, 11, 21), datetime.time(9, 18, 59), 85.0312, 500.0, None, None, None, None, 'CT '),
#  (4503, 'Security_48', 5, datetime.date(2022, 11, 21), datetime.time(9, 19), 63.0625, 2800.0, None, None, None, None, 'CT '),
#  (4515, 'Security_28', 9, datetime.date(2022, 11, 21), datetime.time(9, 19, 3), 93.9688, 6000.0, None, None, None, None, 'T  '),
#  (4518, 'Security_4', 5, datetime.date(2022, 11, 21), datetime.time(9, 19, 4), 62.0625, 7200.0, None, None, None, None, 'T  '),
#  (4519, 'Security_41', 5, datetime.date(2022, 11, 21), datetime.time(9, 19, 4), None, None, 16.0938, 6900.0, None, None, 'Q  '),
#  (4524, 'Security_82', 5, datetime.date(2022, 11, 21), datetime.time(9, 19, 5), 31.0, 4400.0, None, None, None, None, 'CT '),
#  (4526, 'Security_99', 2, datetime.date(2022, 11, 21), datetime.time(9, 19, 6), 87.0, 7300.0, None, None, None, None, 'CT '),
#  (4528, 'Security_97', 3, datetime.date(2022, 11, 21), datetime.time(9, 19, 6), 84.0, 9100.0, None, None, None, None, 'CT '),
#  (4536, 'Security_50', 4, datetime.date(2022, 11, 21), datetime.time(9, 19, 8), None, None, 43.0, 5900.0, None, None, 'Q  '),
#  (4537, 'Security_69', 5, datetime.date(2022, 11, 21), datetime.time(9, 19, 8), 77.0, 8400.0, None, None, None, None, 'T  '),
#  (4542, 'Security_32', 7, datetime.date(2022, 11, 21), datetime.time(9, 19, 10), 82.0, 3900.0, None, None, None, None, 'T  '),
#  (4577, 'Security_25', 5, datetime.date(2022, 11, 21), datetime.time(9, 19, 18), 75.0, 1200.0, None, None, None, None, 'T  '),
#  (4584, 'Security_19', 4, datetime.date(2022, 11, 21), datetime.time(9, 19, 20), 1.0, 2300.0, None, None, None, None, 'T  '),
#  (4589, 'Security_51', 5, datetime.date(2022, 11, 21), datetime.time(9, 19, 21), None, None, 32.0312, 3900.0, None, None, 'Q  '),
#  (4597, 'Security_40', 4, datetime.date(2022, 11, 21), datetime.time(9, 19, 23), 10.0, 6600.0, None, None, None, None, 'T  '),
#  (4599, 'Security_18', 8, datetime.date(2022, 11, 21), datetime.time(9, 19, 24), None, None, None, None, 44.9688, 5400.0, 'Q  '),
#  (4606, 'Security_32', 8, datetime.date(2022, 11, 21), datetime.time(9, 19, 26), 82.0, 4200.0, None, None, None, None, 'T  '),
#  (4660, 'Security_16', 10, datetime.date(2022, 11, 21), datetime.time(9, 19, 39), None, None, None, None, 97.0625, 9300.0, 'Q  '),
#  (4669, 'Security_23', 4, datetime.date(2022, 11, 21), datetime.time(9, 19, 42), None, None, 52.9375, 3000.0, None, None, 'Q  '),
#  (4674, 'Security_48', 6, datetime.date(2022, 11, 21), datetime.time(9, 19, 43), 63.0625, 7000.0, None, None, None, None, 'T  '),
#  (4678, 'Security_73', 6, datetime.date(2022, 11, 21), datetime.time(9, 19, 44), None, None, 65.9688, 6100.0, None, None, 'Q  '),
#  (4679, 'Security_42', 1, datetime.date(2022, 11, 21), datetime.time(9, 19, 44), None, None, 41.0938, 2400.0, None, None, 'Q  '),
#  (4703, 'Security_41', 6, datetime.date(2022, 11, 21), datetime.time(9, 19, 50), None, None, 16.0938, 1400.0, None, None, 'Q  '),
#  (4705, 'Security_77', 6, datetime.date(2022, 11, 21), datetime.time(9, 19, 51), None, None, 49.0938, 2900.0, None, None, 'Q  '),
#  (4713, 'Security_70', 6, datetime.date(2022, 11, 21), datetime.time(9, 19, 53), 61.0312, 6500.0, None, None, None, None, 'T  '),
#  (4720, 'Security_36', 9, datetime.date(2022, 11, 21), datetime.time(9, 19, 54), None, None, None, None, 50.9688, 3000.0, 'Q  '),
#  (4724, 'Security_22', 8, datetime.date(2022, 11, 21), datetime.time(9, 19, 55), 18.0312, 7300.0, None, None, None, None, 'CT '),
#  (4730, 'Security_54', 8, datetime.date(2022, 11, 21), datetime.time(9, 19, 57), 26.9688, 8900.0, None, None, None, None, 'T  '),
#  (4735, 'Security_33', 8, datetime.date(2022, 11, 21), datetime.time(9, 19, 58), None, None, 69.0312, 2300.0, None, None, 'Q  '),
#  (4749, 'Security_35', 5, datetime.date(2022, 11, 21), datetime.time(9, 20, 2), None, None, None, None, 57.9062, 1800.0, 'Q  '),
#  (4750, 'Security_70', 7, datetime.date(2022, 11, 21), datetime.time(9, 20, 2), None, None, None, None, 61.0938, 9900.0, 'Q  '),
#  (4751, 'Security_81', 6, datetime.date(2022, 11, 21), datetime.time(9, 20, 2), 95.0, 4400.0, None, None, None, None, 'T  '),
#  (4754, 'Security_9', 4, datetime.date(2022, 11, 21), datetime.time(9, 20, 3), 61.0, 2100.0, None, None, None, None, 'T  '),
#  (4755, 'Security_73', 7, datetime.date(2022, 11, 21), datetime.time(9, 20, 3), 65.9688, 6800.0, None, None, None, None, 'T  '),
#  (4776, 'Security_62', 3, datetime.date(2022, 11, 21), datetime.time(9, 20, 8), 53.0, 6700.0, None, None, None, None, 'T  '),
#  (4810, 'Security_57', 1, datetime.date(2022, 11, 21), datetime.time(9, 20, 17), 64.0, 1200.0, None, None, None, None, 'T  '),
#  (4811, 'Security_90', 4, datetime.date(2022, 11, 21), datetime.time(9, 20, 17), None, None, 50.0625, 4300.0, None, None, 'Q  '),
# ...
#  (9790, 'Security_85', 11, datetime.date(2022, 11, 21), datetime.time(9, 41, 15), 27.0938, 6200.0, None, None, None, None, 'CT '),
#  (9822, 'Security_8', 11, datetime.date(2022, 11, 21), datetime.time(9, 41, 23), None, None, None, None, 81.0312, 2900.0, 'Q  '),
#  (9833, 'Security_21', 9, datetime.date(2022, 11, 21), datetime.time(9, 41, 26), None, None, None, None, 11.9688, 4100.0, 'Q  '),
#  (9845, 'Security_75', 14, datetime.date(2022, 11, 21), datetime.time(9, 41, 29), 35.0938, 2100.0, None, None, None, None, 'T  '),
#  (9865, 'Security_71', 15, datetime.date(2022, 11, 21), datetime.time(9, 41, 34), None, None, 92.0625, 1700.0, None, None, 'Q  '),
#  (11235, 'Security_18', 17, datetime.date(2022, 11, 21), datetime.time(9, 47, 22), None, None, None, None, 45.0625, 3700.0, 'Q  '),
#  (9874, 'Security_34', 6, datetime.date(2022, 11, 21), datetime.time(9, 41, 36), 51.9375, 5400.0, None, None, None, None, 'T  '),
#  (9875, 'Security_77', 14, datetime.date(2022, 11, 21), datetime.time(9, 41, 37), 49.0312, 8900.0, None, None, None, None, 'T  '),
#  (9879, 'Security_38', 13, datetime.date(2022, 11, 21), datetime.time(9, 41, 38), 29.0312, 8500.0, None, None, None, None, 'T  '),
#  (9881, 'Security_94', 11, datetime.date(2022, 11, 21), datetime.time(9, 41, 38), None, None, 66.9375, 4700.0, None, None, 'Q  '),
#  (9896, 'Security_98', 8, datetime.date(2022, 11, 21), datetime.time(9, 41, 42), None, None, 23.0312, 8800.0, None, None, 'Q  '),
#  (9907, 'Security_59', 17, datetime.date(2022, 11, 21), datetime.time(9, 41, 45), None, None, None, None, 90.0938, 700.0, 'Q  '),
#  (9908, 'Security_70', 14, datetime.date(2022, 11, 21), datetime.time(9, 41, 45), None, None, None, None, 60.9688, 8600.0, 'Q  '),
#  (9918, 'Security_51', 12, datetime.date(2022, 11, 21), datetime.time(9, 41, 47), 32.0625, 300.0, None, None, None, None, 'CT '),
#  (9920, 'Security_89', 12, datetime.date(2022, 11, 21), datetime.time(9, 41, 48), 85.0938, 7300.0, None, None, None, None, 'T  '),
#  (9921, 'Security_70', 15, datetime.date(2022, 11, 21), datetime.time(9, 41, 48), None, None, None, None, 60.9688, 400.0, 'Q  '),
#  (9940, 'Security_39', 11, datetime.date(2022, 11, 21), datetime.time(9, 41, 53), None, None, None, None, 76.0938, 2700.0, 'Q  '),
#  (9946, 'Security_36', 17, datetime.date(2022, 11, 21), datetime.time(9, 41, 54), 51.0, 4900.0, None, None, None, None, 'CT '),
#  (9963, 'Security_12', 8, datetime.date(2022, 11, 21), datetime.time(9, 41, 59), None, None, None, None, 19.9688, 8300.0, 'Q  '),
#  (9973, 'Security_85', 12, datetime.date(2022, 11, 21), datetime.time(9, 42, 1), 27.0938, 8100.0, None, None, None, None, 'T  '),
#  (9975, 'Security_13', 12, datetime.date(2022, 11, 21), datetime.time(9, 42, 2), None, None, None, None, 27.0, 4200.0, 'Q  '),
#  (9978, 'Security_93', 11, datetime.date(2022, 11, 21), datetime.time(9, 42, 2), None, None, 73.1875, 1400.0, None, None, 'Q  '),
#  (9995, 'Security_52', 14, datetime.date(2022, 11, 21), datetime.time(9, 42, 7), 20.0625, 9000.0, None, None, None, None, 'T  '),
#  (10015, 'Security_62', 8, datetime.date(2022, 11, 21), datetime.time(9, 42, 12), 53.0, 4900.0, None, None, None, None, 'CT '),
#  (10033, 'Security_58', 7, datetime.date(2022, 11, 21), datetime.time(9, 42, 16), 49.0312, 3700.0, None, None, None, None, 'CT '),
#  (10059, 'Security_80', 7, datetime.date(2022, 11, 21), datetime.time(9, 42, 23), None, None, 80.0312, 6800.0, None, None, 'Q  '),
#  (10061, 'Security_41', 10, datetime.date(2022, 11, 21), datetime.time(9, 42, 23), 16.0625, 1700.0, None, None, None, None, 'CT '),
#  (10081, 'Security_60', 12, datetime.date(2022, 11, 21), datetime.time(9, 42, 28), None, None, None, None, 72.0938, 7800.0, 'Q  '),
#  (11768, 'Security_84', 13, datetime.date(2022, 11, 21), datetime.time(9, 49, 38), 45.9062, 1700.0, None, None, None, None, 'CT '),
#  (10125, 'Security_26', 9, datetime.date(2022, 11, 21), datetime.time(9, 42, 39), None, None, 5.125, 1100.0, None, None, 'Q  '),
#  (10137, 'Security_41', 11, datetime.date(2022, 11, 21), datetime.time(9, 42, 42), 16.0625, 7000.0, None, None, None, None, 'CT '),
#  (10150, 'Security_79', 12, datetime.date(2022, 11, 21), datetime.time(9, 42, 45), None, None, None, None, 39.0, 7700.0, 'Q  '),
#  (10158, 'Security_15', 12, datetime.date(2022, 11, 21), datetime.time(9, 42, 47), None, None, 31.0938, 5000.0, None, None, 'Q  '),
#  (10167, 'Security_42', 3, datetime.date(2022, 11, 21), datetime.time(9, 42, 50), None, None, None, None, 41.0312, 2400.0, 'Q  '),
#  (10170, 'Security_9', 10, datetime.date(2022, 11, 21), datetime.time(9, 42, 50), None, None, None, None, 61.0, 7300.0, 'Q  '),
#  (10202, 'Security_61', 8, datetime.date(2022, 11, 21), datetime.time(9, 42, 59), 53.0625, 2600.0, None, None, None, None, 'CT '),
#  (10217, 'Security_30', 8, datetime.date(2022, 11, 21), datetime.time(9, 43, 2), None, None, None, None, 22.0, 3600.0, 'Q  '),
#  (10239, 'Security_92', 13, datetime.date(2022, 11, 21), datetime.time(9, 43, 8), 2.0625, 2900.0, None, None, None, None, 'CT '),
#  (10244, 'Security_16', 15, datetime.date(2022, 11, 21), datetime.time(9, 43, 9), None, None, None, None, 97.125, 900.0, 'Q  '),
#  (12376, 'Security_11', 15, datetime.date(2022, 11, 21), datetime.time(9, 52, 12), 73.0312, 6900.0, None, None, None, None, 'T  '),
#  (10251, 'Security_7', 8, datetime.date(2022, 11, 21), datetime.time(9, 43, 11), 47.0312, 9800.0, None, None, None, None, 'CT '),
#  (10267, 'Security_70', 16, datetime.date(2022, 11, 21), datetime.time(9, 43, 15), 60.9688, 9800.0, None, None, None, None, 'CT '),
#  (10269, 'Security_84', 12, datetime.date(2022, 11, 21), datetime.time(9, 43, 15), None, None, 45.9062, 3500.0, None, None, 'Q  '),
#  (10272, 'Security_82', 8, datetime.date(2022, 11, 21), datetime.time(9, 43, 16), 31.0, 5000.0, None, None, None, None, 'T  '),
#  (10281, 'Security_27', 12, datetime.date(2022, 11, 21), datetime.time(9, 43, 18), None, None, 31.1562, 8400.0, None, None, 'Q  '),
#  (10282, 'Security_85', 13, datetime.date(2022, 11, 21), datetime.time(9, 43, 19), None, None, 27.0938, 7000.0, None, None, 'Q  '),
#  (10287, 'Security_17', 11, datetime.date(2022, 11, 21), datetime.time(9, 43, 20), 76.0312, 3000.0, None, None, None, None, 'T  '),
#  (10291, 'Security_47', 12, datetime.date(2022, 11, 21), datetime.time(9, 43, 21), 63.0938, 9200.0, None, None, None, None, 'CT '),
#  (10295, 'Security_57', 2, datetime.date(2022, 11, 21), datetime.time(9, 43, 22), None, None, 64.0938, 4100.0, None, None, 'Q  '),
#  (10314, 'Security_86', 10, datetime.date(2022, 11, 21), datetime.time(9, 43, 27), 29.0938, 8900.0, None, None, None, None, 'CT '),
#  (10320, 'Security_70', 17, datetime.date(2022, 11, 21), datetime.time(9, 43, 29), 60.9688, 1200.0, None, None, None, None, 'CT '),
#  (10335, 'Security_51', 13, datetime.date(2022, 11, 21), datetime.time(9, 43, 32), None, None, None, None, 32.0938, 1200.0, 'Q  '),
#  (10337, 'Security_9', 11, datetime.date(2022, 11, 21), datetime.time(9, 43, 33), None, None, 61.0312, 3800.0, None, None, 'Q  '),
#  (10349, 'Security_31', 9, datetime.date(2022, 11, 21), datetime.time(9, 43, 36), 67.9688, 4500.0, None, None, None, None, 'T  '),
#  (10352, 'Security_70', 18, datetime.date(2022, 11, 21), datetime.time(9, 43, 37), None, None, None, None, 61.0, 8800.0, 'Q  '),
#  (10355, 'Security_35', 12, datetime.date(2022, 11, 21), datetime.time(9, 43, 37), 57.9062, 9400.0, None, None, None, None, 'CT '),
#  (10369, 'Security_88', 9, datetime.date(2022, 11, 21), datetime.time(9, 43, 41), None, None, None, None, 32.0312, 5500.0, 'Q  '),
#  (10375, 'Security_72', 12, datetime.date(2022, 11, 21), datetime.time(9, 43, 43), 80.875, 3200.0, None, None, None, None, 'CT '),
#  (10380, 'Security_1', 14, datetime.date(2022, 11, 21), datetime.time(9, 43, 44), None, None, None, None, 4.0625, 6600.0, 'Q  '),
#  (10381, 'Security_55', 11, datetime.date(2022, 11, 21), datetime.time(9, 43, 44), 27.0, 9800.0, None, None, None, None, 'T  '),
#  (10384, 'Security_34', 7, datetime.date(2022, 11, 21), datetime.time(9, 43, 45), 51.9375, 4500.0, None, None, None, None, 'T  '),
#  (10403, 'Security_75', 15, datetime.date(2022, 11, 21), datetime.time(9, 43, 50), None, None, None, None, 35.125, 1100.0, 'Q  '),
#  (10405, 'Security_23', 15, datetime.date(2022, 11, 21), datetime.time(9, 43, 51), None, None, 53.0312, 800.0, None, None, 'Q  '),
#  (10407, 'Security_54', 17, datetime.date(2022, 11, 21), datetime.time(9, 43, 51), None, None, 27.125, 8100.0, None, None, 'Q  '),
#  (10413, 'Security_11', 14, datetime.date(2022, 11, 21), datetime.time(9, 43, 53), 73.0312, 1000.0, None, None, None, None, 'CT '),
#  (10420, 'Security_9', 12, datetime.date(2022, 11, 21), datetime.time(9, 43, 54), None, None, 61.0625, 1300.0, None, None, 'Q  '),
#  (10426, 'Security_25', 10, datetime.date(2022, 11, 21), datetime.time(9, 43, 56), 75.0625, 1300.0, None, None, None, None, 'T  '),
#  (10430, 'Security_30', 9, datetime.date(2022, 11, 21), datetime.time(9, 43, 57), 22.0, 4400.0, None, None, None, None, 'T  '),
#  (10435, 'Security_28', 12, datetime.date(2022, 11, 21), datetime.time(9, 43, 58), None, None, 93.9688, 7500.0, None, None, 'Q  '),
#  (10437, 'Security_24', 15, datetime.date(2022, 11, 21), datetime.time(9, 43, 59), 46.0625, 2900.0, None, None, None, None, 'T  '),
#  (10450, 'Security_20', 10, datetime.date(2022, 11, 21), datetime.time(9, 44, 2), None, None, 55.0312, 3300.0, None, None, 'Q  '),
#  (10456, 'Security_83', 13, datetime.date(2022, 11, 21), datetime.time(9, 44, 3), 82.1562, 8000.0, None, None, None, None, 'CT '),
#  (10479, 'Security_56', 6, datetime.date(2022, 11, 21), datetime.time(9, 44, 9), 25.0625, 2200.0, None, None, None, None, 'T  '),
#  (10480, 'Security_3', 8, datetime.date(2022, 11, 21), datetime.time(9, 44, 10), None, None, None, None, 45.9688, 4000.0, 'Q  '),
#  (10500, 'Security_59', 18, datetime.date(2022, 11, 21), datetime.time(9, 44, 15), 90.0938, 3300.0, None, None, None, None, 'CT '),
#  (10533, 'Security_20', 11, datetime.date(2022, 11, 21), datetime.time(9, 44, 23), 55.0312, 6400.0, None, None, None, None, 'T  '),
#  (12377, 'Security_14', 10, datetime.date(2022, 11, 21), datetime.time(9, 52, 13), 82.0938, 500.0, None, None, None, None, 'CT '),
#  (10563, 'Security_95', 10, datetime.date(2022, 11, 21), datetime.time(9, 44, 31), 0.96875, 1100.0, None, None, None, None, 'CT '),
#  (10564, 'Security_68', 11, datetime.date(2022, 11, 21), datetime.time(9, 44, 31), None, None, 33.0625, 3600.0, None, None, 'Q  '),
#  (10570, 'Security_21', 10, datetime.date(2022, 11, 21), datetime.time(9, 44, 33), None, None, None, None, 11.9375, 3600.0, 'Q  '),
#  (10575, 'Security_16', 16, datetime.date(2022, 11, 21), datetime.time(9, 44, 34), 97.125, 7500.0, None, None, None, None, 'CT '),
#  (10599, 'Security_46', 19, datetime.date(2022, 11, 21), datetime.time(9, 44, 40), 47.0312, 1400.0, None, None, None, None, 'T  '),
#  (10626, 'Security_23', 16, datetime.date(2022, 11, 21), datetime.time(9, 44, 47), 52.9688, 6700.0, None, None, None, None, 'T  '),
#  (10655, 'Security_42', 4, datetime.date(2022, 11, 21), datetime.time(9, 44, 54), 41.0312, 6200.0, None, None, None, None, 'T  '),
#  (10669, 'Security_45', 5, datetime.date(2022, 11, 21), datetime.time(9, 44, 57), None, None, 87.0, 3900.0, None, None, 'Q  '),
#  (10672, 'Security_24', 16, datetime.date(2022, 11, 21), datetime.time(9, 44, 58), 46.0625, 4500.0, None, None, None, None, 'CT '),
#  (10678, 'Security_10', 16, datetime.date(2022, 11, 21), datetime.time(9, 45), None, None, None, None, 70.125, 4300.0, 'Q  '),
#  (10683, 'Security_14', 8, datetime.date(2022, 11, 21), datetime.time(9, 45, 1), None, None, None, None, 82.0938, 6700.0, 'Q  '),
#  (10703, 'Security_27', 13, datetime.date(2022, 11, 21), datetime.time(9, 45, 6), None, None, 31.0625, 2600.0, None, None, 'Q  '),
#  (10713, 'Security_9', 13, datetime.date(2022, 11, 21), datetime.time(9, 45, 9), None, None, None, None, 61.0, 500.0, 'Q  '),
#  (10714, 'Security_92', 14, datetime.date(2022, 11, 21), datetime.time(9, 45, 10), 2.0625, 4000.0, None, None, None, None, 'T  '),
#  (10730, 'Security_91', 13, datetime.date(2022, 11, 21), datetime.time(9, 45, 14), None, None, None, None, 42.0, 4100.0, 'Q  '),
#  (10732, 'Security_58', 8, datetime.date(2022, 11, 21), datetime.time(9, 45, 14), None, None, 49.125, 3500.0, None, None, 'Q  '),
#  (10734, 'Security_95', 11, datetime.date(2022, 11, 21), datetime.time(9, 45, 15), None, None, None, None, 1.03125, 3200.0, 'Q  '),
#  (10737, 'Security_40', 12, datetime.date(2022, 11, 21), datetime.time(9, 45, 15), None, None, 10.0312, 9100.0, None, None, 'Q  '),
#  (10754, 'Security_20', 12, datetime.date(2022, 11, 21), datetime.time(9, 45, 20), 55.0312, 8600.0, None, None, None, None, 'CT '),
#  (10787, 'Security_39', 12, datetime.date(2022, 11, 21), datetime.time(9, 45, 28), 76.0938, 800.0, None, None, None, None, 'CT '),
#  (10800, 'Security_69', 10, datetime.date(2022, 11, 21), datetime.time(9, 45, 31), None, None, 77.0625, 1100.0, None, None, 'Q  '),
#  (10802, 'Security_86', 11, datetime.date(2022, 11, 21), datetime.time(9, 45, 32), 29.0938, 8800.0, None, None, None, None, 'T  '),
#  (10803, 'Security_34', 8, datetime.date(2022, 11, 21), datetime.time(9, 45, 32), 51.9375, 3400.0, None, None, None, None, 'CT '),
#  (10805, 'Security_74', 9, datetime.date(2022, 11, 21), datetime.time(9, 45, 32), 93.0, 6400.0, None, None, None, None, 'CT '),
#  (10806, 'Security_3', 9, datetime.date(2022, 11, 21), datetime.time(9, 45, 33), None, None, 45.9688, 9100.0, None, None, 'Q  '),
#  (10808, 'Security_49', 7, datetime.date(2022, 11, 21), datetime.time(9, 45, 33), None, None, None, None, 62.0938, 9900.0, 'Q  '),
#  (10814, 'Security_76', 9, datetime.date(2022, 11, 21), datetime.time(9, 45, 35), 83.0625, 8500.0, None, None, None, None, 'CT '),
#  (10824, 'Security_27', 14, datetime.date(2022, 11, 21), datetime.time(9, 45, 37), 31.0625, 7600.0, None, None, None, None, 'CT '),
#  (10828, 'Security_1', 15, datetime.date(2022, 11, 21), datetime.time(9, 45, 38), 4.0625, 6700.0, None, None, None, None, 'CT '),
#  (10853, 'Security_58', 9, datetime.date(2022, 11, 21), datetime.time(9, 45, 44), 49.0312, 4200.0, None, None, None, None, 'CT '),
#  (10873, 'Security_12', 9, datetime.date(2022, 11, 21), datetime.time(9, 45, 49), None, None, 20.0625, 5100.0, None, None, 'Q  '),
#  (10886, 'Security_1', 16, datetime.date(2022, 11, 21), datetime.time(9, 45, 53), 4.0625, 9800.0, None, None, None, None, 'T  '),
#  (10887, 'Security_56', 7, datetime.date(2022, 11, 21), datetime.time(9, 45, 53), 25.0625, 6500.0, None, None, None, None, 'T  '),
#  (10893, 'Security_64', 11, datetime.date(2022, 11, 21), datetime.time(9, 45, 54), None, None, None, None, 56.0625, 7800.0, 'Q  '),
#  (10894, 'Security_55', 12, datetime.date(2022, 11, 21), datetime.time(9, 45, 55), 27.0, 9400.0, None, None, None, None, 'CT '),
#  (10898, 'Security_6', 10, datetime.date(2022, 11, 21), datetime.time(9, 45, 56), None, None, None, None, 57.9375, 3600.0, 'Q  '),
#  (10913, 'Security_14', 9, datetime.date(2022, 11, 21), datetime.time(9, 46), None, None, 82.1875, 8500.0, None, None, 'Q  '),
#  (10929, 'Security_86', 12, datetime.date(2022, 11, 21), datetime.time(9, 46, 4), 29.0938, 3500.0, None, None, None, None, 'CT '),
#  (10954, 'Security_89', 13, datetime.date(2022, 11, 21), datetime.time(9, 46, 10), None, None, 85.1562, 4200.0, None, None, 'Q  '),
#  (10963, 'Security_79', 13, datetime.date(2022, 11, 21), datetime.time(9, 46, 13), 39.0, 6600.0, None, None, None, None, 'CT '),
#  (10979, 'Security_94', 12, datetime.date(2022, 11, 21), datetime.time(9, 46, 17), 66.9375, 200.0, None, None, None, None, 'CT '),
#  (10981, 'Security_16', 17, datetime.date(2022, 11, 21), datetime.time(9, 46, 17), 97.125, 800.0, None, None, None, None, 'T  '),
#  (10987, 'Security_2', 14, datetime.date(2022, 11, 21), datetime.time(9, 46, 19), None, None, 90.0938, 1300.0, None, None, 'Q  '),
#  (10993, 'Security_24', 17, datetime.date(2022, 11, 21), datetime.time(9, 46, 21), 46.0625, 1700.0, None, None, None, None, 'T  '),
#  (10998, 'Security_29', 9, datetime.date(2022, 11, 21), datetime.time(9, 46, 22), None, None, 11.125, 9300.0, None, None, 'Q  '),
#  ...]

# %%
# %%time
# %%sql
--2.
SELECT SUM(TradePrice * TradeSize) / SUM(TradeSize) AS volume_weighted_price
FROM ticks
WHERE Id='Security_1'
  AND TradeDate='2022.11.21'
  AND ts >= '9:00:00.00'
  AND ts < '12:00:00.00';
# Out:
#    postgresql://alfredo.leon@localhost/findata
#  * postgresql://postgres@localhost/findata
# 1 rows affected.
# CPU times: user 6.6 ms, sys: 18.8 ms, total: 25.4 ms
# Wall time: 599 ms
# [(3.99304008908686,)]

# %%
# %%time
# %%sql
--3.
WITH closingpricetoday AS(
  SELECT DISTINCT Id, FIRST_VALUE(TradePrice) OVER (PARTITION BY Id ORDER BY ts DESC) AS TradePrice
  FROM ticks
  WHERE TradeDate='2022.11.22'
    AND TradePrice > 0.0
), closingpricepreviousday AS(
  SELECT DISTINCT Id, FIRST_VALUE(TradePrice) OVER (PARTITION BY Id ORDER BY ts DESC) AS TradePrice
  FROM ticks
  WHERE TradeDate='2022.11.23'
    AND TradePrice > 0.0
)
SELECT
  closingpricetoday.Id,
  --closingpricetoday.TradePrice, closingpricepreviousday.TradePrice,
  (closingpricetoday.TradePrice
        -closingpricepreviousday.TradePrice)*100/closingpricepreviousday.TradePrice
  AS loss_percentage
FROM closingpricetoday JOIN closingpricepreviousday USING(Id)
ORDER BY loss_percentage
LIMIT 10;
# Out:
#    postgresql://alfredo.leon@localhost/findata
#  * postgresql://postgres@localhost/findata
# 10 rows affected.
# CPU times: user 8.43 ms, sys: 23.3 ms, total: 31.8 ms
# Wall time: 1.23 s
# [('Security_382', -70.0),
#  ('Security_96', -62.5),
#  ('Security_999', -59.09090909090909),
#  ('Security_322', -33.333333333333336),
#  ('Security_524', -26.666666666666668),
#  ('Security_656', -25.806451612903224),
#  ('Security_95', -23.529411764705884),
#  ('Security_19', -21.05263157894737),
#  ('Security_980', -19.791666666666668),
#  ('Security_799', -15.584415584415584)]
